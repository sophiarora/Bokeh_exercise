# %%
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="619bf46a-41b7-40c3-8781-bd07da5ce995">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.sampledata.autompg import autompg_clean as df
from bokeh.transform import factor_cmap

df.cyl = df.cyl.astype(str)
df.yr = df.yr.astype(str)

group = df.groupby(('cyl', 'mfr'))
source = ColumnDataSource(group)

p = figure(plot_width=800, plot_height=300, title="Mean MPG by # Cylinders and Manufacturer",
           x_range=group, toolbar_location=None, tools="")

p.xgrid.grid_line_color = None
p.xaxis.axis_label = "Manufacturer grouped by # Cylinders"
p.xaxis.major_label_orientation = 1.2

index_cmap = factor_cmap('cyl_mfr', palette=['#2b83ba', '#abdda4', '#ffffbf', '#fdae61', '#d7191c'], 
                         factors=sorted(df.cyl.unique()), end=1)

p.vbar(x='cyl_mfr', top='mpg_mean', width=1, source=source,
       line_color="white", fill_color=index_cmap, 
       hover_line_color="black", hover_fill_color=index_cmap)

p.add_tools(HoverTool(tooltips=[("MPG", "@mpg_mean"), ("Cyl, Mfr", "@cyl_mfr")]))

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6e8243b-b680-4483-93e0-17652faf20b5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("e6e8243b-b680-4483-93e0-17652faf20b5");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6e8243b-b680-4483-93e0-17652faf20b5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6e8243b-b680-4483-93e0-17652faf20b5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f3d5a20e-5a12-46e6-a346-826ca2811cba":{"roots":{"references":[{"attributes":{},"id":"d2984647-1acf-44ee-915a-afd66f905de8","type":"BasicTicker"},{"attributes":{"callback":null,"factors":[["3","mazda"],["4","amc"],["4","audi"],["4","bmw"],["4","buick"],["4","capri"],["4","chevrolet"],["4","chrysler"],["4","datsun"],["4","dodge"],["4","fiat"],["4","ford"],["4","honda"],["4","mazda"],["4","mercedes"],["4","mercury"],["4","nissan"],["4","oldsmobile"],["4","opel"],["4","peugeot"],["4","plymouth"],["4","pontiac"],["4","renault"],["4","saab"],["4","subaru"],["4","toyota"],["4","triumph"],["4","volkswagen"],["4","volvo"],["5","audi"],["5","mercedes"],["6","amc"],["6","buick"],["6","chevrolet"],["6","chrysler"],["6","datsun"],["6","dodge"],["6","ford"],["6","mercedes"],["6","mercury"],["6","oldsmobile"],["6","peugeot"],["6","plymouth"],["6","pontiac"],["6","toyota"],["6","volvo"],["8","amc"],["8","buick"],["8","cadillac"],["8","chevrolet"],["8","chrysler"],["8","dodge"],["8","ford"],["8","hi"],["8","mercury"],["8","oldsmobile"],["8","plymouth"],["8","pontiac"]]},"id":"07ded1c8-58ab-4722-bb4e-75927475c606","type":"FactorRange"},{"attributes":{"dimension":1,"plot":{"id":"290fa90a-ce2c-4b0c-accf-3b4a6ebf1582","subtype":"Figure","type":"Plot"},"ticker":{"id":"d2984647-1acf-44ee-915a-afd66f905de8","type":"BasicTicker"}},"id":"56ec7221-bff8-43a7-bdc4-3a836f6eb086","type":"Grid"},{"attributes":{},"id":"1c421072-127a-41f7-af1e-4602ee21e8d3","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"field":"cyl_mfr","transform":{"id":"0ebfd759-9047-44ec-a837-f4456925d59a","type":"CategoricalColorMapper"}},"top":{"field":"mpg_mean"},"width":{"value":1},"x":{"field":"cyl_mfr"}},"id":"f641714e-dcd9-4f22-9a8b-75da1afbc498","type":"VBar"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"eff3c795-8765-47c8-b6c7-416a35120baa","type":"HoverTool"}]},"id":"5f4c1976-e170-4513-9118-54449268d242","type":"Toolbar"},{"attributes":{"callback":null,"tooltips":[["MPG","@mpg_mean"],["Cyl, Mfr","@cyl_mfr"]]},"id":"eff3c795-8765-47c8-b6c7-416a35120baa","type":"HoverTool"},{"attributes":{"plot":null,"text":"Mean MPG by # Cylinders and Manufacturer"},"id":"db6e1576-58f5-4d72-be68-5ca95bb43147","type":"Title"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"290fa90a-ce2c-4b0c-accf-3b4a6ebf1582","subtype":"Figure","type":"Plot"},"ticker":{"id":"8b783f1e-f4de-4a97-94a9-c3c1c05de2af","type":"CategoricalTicker"}},"id":"59e6e8cf-a3ff-437e-b1bb-67537a693f39","type":"Grid"},{"attributes":{"formatter":{"id":"1c421072-127a-41f7-af1e-4602ee21e8d3","type":"BasicTickFormatter"},"plot":{"id":"290fa90a-ce2c-4b0c-accf-3b4a6ebf1582","subtype":"Figure","type":"Plot"},"ticker":{"id":"d2984647-1acf-44ee-915a-afd66f905de8","type":"BasicTicker"}},"id":"00ccbad8-7d70-485f-9d80-b38397485267","type":"LinearAxis"},{"attributes":{},"id":"8b783f1e-f4de-4a97-94a9-c3c1c05de2af","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["weight_min","accel_50%","hp_count","hp_mean","accel_mean","displ_std","mpg_count","accel_max","hp_50%","accel_25%","mpg_mean","displ_75%","hp_25%","mpg_std","hp_max","hp_std","mpg_75%","weight_75%","displ_min","mpg_max","weight_50%","cyl_mfr","weight_count","accel_75%","accel_count","hp_75%","weight_mean","mpg_min","accel_min","weight_max","weight_25%","mpg_25%","hp_min","accel_std","mpg_50%","displ_max","displ_25%","displ_50%","displ_count","displ_mean","weight_std"],"data":{"accel_25%":{"__ndarray__":"...","dtype":"float64","shape":[58]},"accel_50%":{"__ndarray__":"...","dtype":"float64","shape":[58]},"accel_75%":{"__ndarray__":"...","dtype":"float64","shape":[58]},"accel_count":{"__ndarray__":"...","dtype":"float64","shape":[58]},"accel_max":{"__ndarray__":"...","dtype":"float64","shape":[58]},"accel_mean":{"__ndarray__":"...","dtype":"float64","shape":[58]},"accel_min":{"__ndarray__":"...","dtype":"float64","shape":[58]},"accel_std" ...
